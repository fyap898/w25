# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-10, 11, 100)
y1 = np.sin(x)
y2 = np.abs(x)

plt.plot(x, y1, label="$y = sin(x)$")
plt.plot(x, y2, label="$y = |x|$")
plt.grid(True)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.savefig("../figures/02-differentiable.png")

# %%
x1 = np.linspace(-10, 10, 100)
x2 = np.linspace(-10, 10, 100)
X1, X2 = np.meshgrid(x1, x2)
Y = 2 * X1 + X2 + X1 * X2

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X1, X2, Y, alpha=0.8, cmap="viridis")
fig.colorbar(surf)
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.title("$y = 2x_1 + x_2 + x_1x_2$")
plt.savefig("../figures/02-surface.png")

# %%
# double check my answer!
A = np.array([
    [2,0],
    [1,3],
    [-4,5]
])

B = np.array([
    [-1, 0, 1],
    [1, 3, 7]
])

A @ B
# Out:
# array([[-2,  0,  2],
#        [ 2,  9, 22],
#        [ 9, 15, 31]])

# %%
A = np.array([
    [1,2],
    [3,4]
])

np.linalg.inv(A)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
x = np.linspace(-5, 5, 100)
y = x**2 + 5
plt.plot(x, y, label="$y = x^2 + 5$")
dy_dx = np.gradient(y, x)
plt.plot(x, dy_dx, label=r"$\frac{dy}{dx} = 2x$")
plt.annotate(r"$\frac{dy}{dx}$ = 0", (0,0), xytext=(-1, 10), arrowprops={"arrowstyle": "->"})
plt.legend()
plt.show()
